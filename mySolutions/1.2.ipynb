# %%
3 + 4*5
# Out:
# 23

# %%
23.45 / 1e-02
# Out:
# 2345.0

# %%
x = 1172.5
x.as_integer_ratio()
x.is_integer()
y = 12345
y.numerator
y.denominator
y.bit_length()
# Out:
# 14

# %%
symbols = 'AAPL IBM MSFT YHOO SCO'
